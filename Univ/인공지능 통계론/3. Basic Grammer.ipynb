# %%
# ------ 문자열 ------

string1 = 'welcome'
string2 = ' to'
string3 = ' python'

r = string1 + string2 + string3 # + 연산을 통해 string 합치기

len(r) # 문자열 길이 구하기

r[12] # 문자열 인덱싱, index는 0부터 시작함 <-> R
r[12:15] # 문자열 슬라이싱. 끝 인덱스 포함x
r[-10:-1] # 맨 뒤 인덱스는 -1부터 시작
r[:12] # 맨 처음부터 12인덱스(미포함) 까지를 의미

# 문자열 함수
r.upper() # 문자열 모두 대문자
r.lower() # 문자열 모두 소문자
r.index('e') # 문자 'e'의 인덱스 반환
r.index('lc') # 가장 앞 문자 (l)의 인덱스 반환
r.replace('to','from') # to -> from으로 대체

name = '김원구'
year = 4

# 문자열 출력 포매팅
print('이름은 %s, 학년은 %d' %(name, year))
print('이름은 {}, 학년은 {}'.format(name,year))
print(f'이름은 {name}, 학년은 {year}')


# ------ 숫자형 ------

inum = 3 # int
fnum = 3.1 # float
onum = 0o10 # octal (8)
hnum = 0x10 # hecadecimal (16)

type(5) # 자료형 반환

# ------ 리스트 ------

x = [2,3,'c',True, [1,'a']] # 다양한 형태의 원소 가능
x2 = [[1,2,3],[4,5,6]] # 2차원 리스트 (==2차원 행렬)
x2[0][1] # 0번째 행 1번째 열의 원소 (2)
[row[2] for row in x2] # 3열(2번째 열)에 해당하는 값. 3,6

x1 = [1,2,4,3]
x2 = [5,6,7,8]
x1 + 2 # 오류 발생
x1 + [2] # 마지막 요소에 추가

x1[2] # 리스트 인덱싱. 문자열 인덱싱과 동일
x1[2:3] # 리스트 슬라이싱

# 리스트 함수

x1.append(x) # 마지막 인덱스에 요소 x추가
x1.insert(i,x) # i번째 인덱스에 x 삽입
x1.remove(x) # 요소 x를 삭제
del x1[i] # i번째 요소 삭제
x1.sort() # 리스트를 오름차순 정렬
x1.reverse() # 리스트를 거꾸로 뒤집음
x1.extend(x2) # 리스트 x1, x2를 합침
#x1.index(x) # 요소 x가 처음으로 나온 위치 반환
x1.pop() # 마지막 요소를 제거하고 그 값을 반환

# 리스트와 문자열의 호환
lst = ['a,','b','c','d']
joined1 = ' '.join(lst) # 공백을 리스트 요소 사이에 삽입하여 문자열 생성
joined2 = ','.join(lst) # 쉼표를 요소 사이에 삽입


# ------ 백터 및 행렬 연산 ------

import numpy as np
y1 = np.array([1,2,3,4]) # (4, ) vector
y2 = np.array([5,6,7,8]) # (4, ) vector
xm = np.array([[1,2,3],[4,5,6]]) # (2,3) matrix
xm.reshape(3,2) # (2,3) -> (3,2)

xm[1,2] # 행렬의 1번째 행 2번째 열(0번째 부터 시작)
xm[:,0] # 모든 행에 대해 0번째 열

mx1 = np.array(range(1,10)).reshape(3,3) # 0~9, (3,3)
mx2 = np.append(mx1,np.array([10,20,30]).reshape(1,3),
                axis = 0) # 행에 대한 추가. (3,3) -> (4,3)
mx3 = np.append(mx1, np.array([10,20,30]).reshape(3,1),
                axis = 1) # 열에 대한 추가. (3,3) -> (3,4)

mx4 = np.delete(mx1, 0, axis=0) # 0번째 행 삭제 (3,3) -> (2,3)
mx5 = np.delete(mx1, [0,1], axis=1) # 0,1번째 열 삭제 (3,3) -> (3,1)

mx6 = np.insert(mx1, 1, np.array([10,20,30]), 
                axis=0) # 1번째 행에 추가. (3,3) -> (4,3)
mx7 = np.insert(mx1, 1, np.array(range(10,100,10)).reshape(3,3),
                axis=1) # 1번째 열에 추가. (3,3) -> (6,3)

mx8 = np.matmul(mx1,mx3) # 행렬 곱. (3,3) x (3,4) -> (3,4)


# ------ Tuple ------

t1 = (1,2,3) # 리스트와 비슷하지만 삭제, 수정이 불가능


# ------ Dictionary ------

dic1 = {'Name':'Seung',
        'Year':3,
        'Major':['DataScience','Software']}

dic1['Name'] # 키 값을 통해 딕셔너리 접근
dic1[4] = 'Fourth Value' # 새로운 데이터 생성
dic1['Name'] = 'Bin' # 기존의 Key와 동일하므로, 값을 교체함
del dic1['Year'] # 딕셔너리 키:값 삭제

dic1.keys() # Key값 얻기
dic1.values() # Value 값 얻기
dic1.items() # Key Value 얻기
dic1.clear() # 딕셔너리 클리어
# Out:
# 이름은 김원구, 학년은 4
# 이름은 김원구, 학년은 4
# 이름은 김원구, 학년은 4
# (4,)

# %%
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])
