# %%
import requests
import json

city = "Seoul"
appid= "#######################"
lang = "kr"

# OpenWeather의 Current weather data 페이지를 참고하여
# 도시, api id, 언어를 입력해주세요
api = "http://api.openweathermap.org/data/2.5/weather" + '___' + '_____' + '_____'

response = requests.get(api)
result = response.text

# 문자열 형태로 받아온 데이터인 result를
# json type으로 변환해 주세요
data = ____.____(result)

# json으로 변환된 결과를 확인해보세요
print(data)

# %%
"""
data = {    
    "coord": {'lon': 126.9778, 'lat': 37.5683},
    "weather": [{'id': 701, 'main': 'Mist', 'description': '박무', 'icon': '50d'}],
    "base": stations,
    "main": {'temp': 274.36, 'feels_like': 268.31, 'temp_min': 272.91, 
            'temp_max': 276.88, 'pressure': 1022, 'humidity': 61},
    "visibility": 1200,
    "wind": {'speed': 8.23, 'deg': 280},
    "clouds": {'all': 75},
    "dt": 1645256680,
    "sys": {'type': 1, 'id': 8105, 'country': 'KR', 
            'sunrise': 1645222653, 'sunset': 1645262082},
    "timezone": 32400,
    "id": 1835848,
    "name": Seoul,
    "cod": 200
    }
"""

# 현재 데이터의 지역 정보를 출력해주세요
print(_________)
# 현재 날씨에 대한 자세한 정보(description)를 출력해주세요 
print(____________)
# 현재 날씨의 바람 속도에 대해 출력해주세요
print(_________)
# 현재 날씨의 최저기온과 최고기온을 출력해주세요
print(_________ + __________)

# %%
import requests
import json

city = "Seoul"
apikey= "617c9b18ce00d7ef8a806dc7ce30e3c7"
lang ="kr"

#http:// + api call 방법(사이트 참고), 다양한 추가 기능 있음
#나만의 api 서버 주소를 만들음
api = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}&lang={lang}"

response = requests.get(api)

#문자열 형태로 반환
#해당 정보가 dict처럼 생겼지만, 타입은 str임
#해당 정보의 생김새를 확인하는 것이 중요함
result = response.text

#문자열을 json type으로 변환 (dict type으로 변환되는데, json은 dict 자료형을 활용함)
data = json.loads(result)

#for key, value in data.items():
#    print(f"{key}: {value}")

# 지역 : name
print(data["name"],"의 날씨입니다.")
# 자세한 날씨 : weather - description
print("날씨는 ",data["weather"][0]["description"],"입니다.")
# 현재 온도 : main - temp
print("현재 온도는 ",data["main"]["temp"],"입니다.")
# 체감 온도 : main - feels_like
print("하지만 체감 온도는 ",data["main"]["feels_like"],"입니다.")
# 최저 기온 : main - temp_min
print("최저 기온은 ",data["main"]["temp_min"],"입니다.")
# 최고 기온 : main - temp_max
print("최고 기온은 ",data["main"]["temp_max"],"입니다.")
# 습도 : main - humidity
print("습도는 ",data["main"]["humidity"],"입니다.")
# 기압 : main - pressure
print("기압은 ",data["main"]["pressure"],"입니다.")
# 풍향 : wind - deg
print("풍향은 ",data["wind"]["deg"],"입니다.")
# 풍속 : wind - speed
print("풍속은 ",data["wind"]["speed"],"입니다.")
# Out:
# coord: {'lon': 126.9778, 'lat': 37.5683}
# weather: [{'id': 701, 'main': 'Mist', 'description': '박무', 'icon': '50d'}]
# base: stations
# main: {'temp': 274.36, 'feels_like': 268.31, 'temp_min': 272.91, 'temp_max': 276.88, 'pressure': 1022, 'humidity': 61}
# visibility: 1200
# wind: {'speed': 8.23, 'deg': 280}
# clouds: {'all': 75}
# dt: 1645256680
# sys: {'type': 1, 'id': 8105, 'country': 'KR', 'sunrise': 1645222653, 'sunset': 1645262082}
# timezone: 32400
# id: 1835848
# name: Seoul
# cod: 200
